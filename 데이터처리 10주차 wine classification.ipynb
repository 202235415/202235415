# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_wine

# %%
wine = load_wine()
wine_data = wine.data
wine_target = wine.target
df_features = wine.feature_names
df_wine = pd.DataFrame(data = wine_data, columns = df_features)
df_wine_target = pd.DataFrame(data = wine_target, columns = {'class'})
#'class' column 추가#
df_wine['class'] = wine.target
df_wine
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#total_data = pd.concat([df_wine, df_wine_target], axis=1)
## 타겟 데이터 추가 안할 시 concat 함수로 data(df_wine)와 target(df_wine_target) 이어붙임##
#total_data

# %%
sns.countplot(data = df_wine, x="class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
df_features = wine.feature_names
df_features
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
df_wine.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# class                           0
# dtype: int64

# %%
df_wine.hist(figsize=(20,10), grid=False, layout=(3, 6), bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'malic_acid'}>,
#         <AxesSubplot:title={'center':'ash'}>,
#         <AxesSubplot:title={'center':'alcalinity_of_ash'}>,
#         <AxesSubplot:title={'center':'magnesium'}>,
#         <AxesSubplot:title={'center':'total_phenols'}>],
#        [<AxesSubplot:title={'center':'flavanoids'}>,
#         <AxesSubplot:title={'center':'nonflavanoid_phenols'}>,
#         <AxesSubplot:title={'center':'proanthocyanins'}>,
#         <AxesSubplot:title={'center':'color_intensity'}>,
#         <AxesSubplot:title={'center':'hue'}>,
#         <AxesSubplot:title={'center':'od280/od315_of_diluted_wines'}>],
#        [<AxesSubplot:title={'center':'proline'}>,
#         <AxesSubplot:title={'center':'class'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df_wine.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
y = df_wine['class']

X = df_wine.drop(['class'],axis=1)

X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.7111111111111111
# [[15  0  0]
#  [ 0 13  5]
#  [ 0  8  4]]

# %%
from sklearn.linear_model import LogisticRegression

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.9777777777777777
# [[14  1  0]
#  [ 0 18  0]
#  [ 0  0 12]]
# C:\Users\test4\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.9555555555555556
# [[14  1  0]
#  [ 0 18  0]
#  [ 0  1 11]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

print ("\n--- Random Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print (confusion_matrix(y_test, pred))
# Out:
# --- Random Forest ---
# 1.0
# [[15  0  0]
#  [ 0 18  0]
#  [ 0  0 12]]

# %%
from sklearn.neighbors import KNeighborsClassifier

k_range = range(1, 113)
find_accuracy = []

for k in k_range:
  find_model = KNeighborsClassifier(n_neighbors = k)
  find_model.fit(X_train, y_train.values.ravel())

  find_accuracy.append(find_model.score(X_test, y_test))
  
plt.plot(k_range, find_accuracy, label="training accuracy")
plt.xlabel("k value")
plt.ylabel("Accuracy")
plt.title("Find Iris Classifier Accuracy")
plt.show()

# %%
var = 'malic_acid'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
df_wine.drop(df_wine[(df_wine['malic_acid']> 4) & (df_wine['class'] < 1.25)].index, inplace=True)

var = 'malic_acid'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
var = 'alcalinity_of_ash'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
df_wine.drop(df_wine[(df_wine['alcalinity_of_ash']> 27.5) & (df_wine['class'] > 0.75)].index, inplace=True)
df_wine.drop(df_wine[(df_wine['alcalinity_of_ash']< 12.5) & (df_wine['class'] > 0.75)].index, inplace=True)

var = 'alcalinity_of_ash'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
var = 'nonflavanoid_phenols'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
df_wine.drop(df_wine[(df_wine['nonflavanoid_phenols']< 0.2) & (df_wine['class'] > 1.75)].index, inplace=True)
df_wine.drop(df_wine[(df_wine['nonflavanoid_phenols']>= 0.5) & (df_wine['class'] < 0.25)].index, inplace=True)

var = 'nonflavanoid_phenols'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
var = 'color_intensity'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
df_wine.drop(df_wine[(df_wine['color_intensity']< 1.5) & (df_wine['class'] < 1.25)].index, inplace=True)
df_wine.drop(df_wine[(df_wine['color_intensity']> 8) & (df_wine['class'] < 0.25)].index, inplace=True)

var = 'color_intensity'
plt.scatter(x = df_wine[var], y = df_wine['class'],)
plt.grid(True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print(accuracy_score(y_test, pred_svm))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.7111111111111111
# [[15  0  0]
#  [ 0 13  5]
#  [ 0  8  4]]

# %%
from sklearn.linear_model import LogisticRegression

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.9777777777777777
# [[14  1  0]
#  [ 0 18  0]
#  [ 0  0 12]]
# C:\Users\test4\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print (accuracy_score(y_test, pred_dt))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.9555555555555556
# [[14  1  0]
#  [ 0 18  0]
#  [ 0  1 11]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

print ("\n--- Random Forest ---")
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
print(accuracy_score(y_test,pred))
print (confusion_matrix(y_test, pred))
# Out:
# --- Random Forest ---
# 1.0
# [[15  0  0]
#  [ 0 18  0]
#  [ 0  0 12]]

# %%
from sklearn.neighbors import KNeighborsClassifier

k_range = range(1, 113)
find_accuracy = []

for k in k_range:
  find_model = KNeighborsClassifier(n_neighbors = k)
  find_model.fit(X_train, y_train.values.ravel())

  find_accuracy.append(find_model.score(X_test, y_test))
  
plt.plot(k_range, find_accuracy, label="training accuracy")
plt.xlabel("k value")
plt.ylabel("Accuracy")
plt.title("Find Iris Classifier Accuracy")
plt.show()
